# %%
import os
import re
import zipfile

import numpy as np
import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
# Out:
# 2023-01-20 10:06:16.799511: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-20 10:06:16.799542: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import glob

with open('/home/uday/Desktop/Table Detection/RetinaNet/train.txt', 'w') as writefile:
    for name in glob.glob('/home/uday/Desktop/Table Detection/images/*.jpg'): 
        print(name)
        name = name.replace('/home/uday/Desktop/Table Detection/images/','')
        #To write names directly to train.txt
        name1=name.replace('.jpg','')
        writefile.write(name1 + "\n")
# Out:
# /home/uday/Desktop/Table Detection/images/1_750001-075.jpg
# /home/uday/Desktop/Table Detection/images/1_2740001-274.jpg
# /home/uday/Desktop/Table Detection/images/3_1410001-141.jpg
# /home/uday/Desktop/Table Detection/images/1_300001-030.jpg
# /home/uday/Desktop/Table Detection/images/4_40001-04.jpg
# /home/uday/Desktop/Table Detection/images/3_1260001-126.jpg
# /home/uday/Desktop/Table Detection/images/3_2450001-245.jpg
# /home/uday/Desktop/Table Detection/images/1_2130001-213.jpg
# /home/uday/Desktop/Table Detection/images/1_810001-081.jpg
# /home/uday/Desktop/Table Detection/images/3_1150001-115.jpg
# /home/uday/Desktop/Table Detection/images/1_990001-099.jpg
# /home/uday/Desktop/Table Detection/images/1_3490001-349.jpg
# /home/uday/Desktop/Table Detection/images/2_590001-059.jpg
# /home/uday/Desktop/Table Detection/images/2_620001-062.jpg
# /home/uday/Desktop/Table Detection/images/3_1060001-106.jpg
# /home/uday/Desktop/Table Detection/images/3_2000001-200.jpg
# ...

# %%
# !retinanet-train --batch-size 7 --steps 35 --epochs 12 \
--weights logos/resnet50_coco_best_v2.1.0.h5 \
--snapshot-path logos/snapshots \
csv retinanet_train.csv retinanet_classes.csv
# Out:
# 2023-01-24 11:25:46.063982: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-24 11:25:46.064014: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Traceback (most recent call last):
#   File "/home/uday/.local/bin/retinanet-train", line 8, in <module>
#     sys.exit(main())
#   File "/home/uday/.local/lib/python3.10/site-packages/keras_retinanet/bin/train.py", line 483, in main
#     train_generator, validation_generator = create_generators(args, backbone.preprocess_image)
#   File "/home/uday/.local/lib/python3.10/site-packages/keras_retinanet/bin/train.py", line 298, in create_generators
#     train_generator = CSVGenerator(
# ...
